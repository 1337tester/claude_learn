# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-3-5-haiku-latest"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
print(dataset)

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)
# Out:
# [{'task': 'Create a JSON configuration for an AWS Lambda function that sets memory size to 256 MB and timeout to 10 seconds'}, {'task': 'Write a Python function that extracts the AWS account ID from an ARN string'}, {'task': 'Develop a regex pattern to validate an AWS S3 bucket name according to naming conventions (lowercase, no spaces, 3-63 characters)'}]

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
        You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

        Original Task:
        <task>
        {test_case["task"]}
        </task>

        Solution to Evaluate:
        <solution>
        {output}
        </solution>

        Output Format
        Provide your evaluation as a structured JSON object with the following fields, in this specific order:
        - "strengths": An array of 1-3 key strengths
        - "weaknesses": An array of 1-3 key areas for improvement
        - "reasoning": A concise explanation of your overall assessment
        - "score": A number between 1-10

        Respond with JSON. Keep your response concise and direct.
        Example response shape:
        {{
            "strengths": string[],
            "weaknesses": string[],
            "reasoning": string,
            "score": number
        }}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "´´´json")
    eval_text = chat(messages, stop_sequences=["´´´"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt=f"""
        Please solve the following task:

        {test_case["task"]}
        """
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "Here's a JSON configuration for an AWS Lambda function with memory set to 256 MB and timeout set to 10 seconds:\n\n```json\n{\n    \"FunctionName\": \"my-lambda-function\",\n    \"MemorySize\": 256,\n    \"Timeout\": 10\n}\n```\n\nKey points about this configuration:\n- `FunctionName` specifies the name of the Lambda function\n- `MemorySize` is set to 256 MB\n- `Timeout` is set to 10 seconds\n\nThis JSON can be used with AWS CLI or CloudFormation to configure a Lambda function's memory and timeout settings.\n\nWould you like me to elaborate on any part of the configuration?",
#     "test_case": {
#       "task": "Create a JSON configuration for an AWS Lambda function that sets memory size to 256 MB and timeout to 10 seconds"
#     },
#     "score": 6,
#     "reasoning": "The solution provides a basic, technically correct configuration for Lambda memory and timeout settings, but lacks critical details needed for a complete function deployment. While the core task is met, the configuration would require additional properties to be fully functional."
#   },
#   {
#     "output": "Here's a Python function to extract the AWS account ID from an ARN (Amazon Resource Name) string:\n\n```python\ndef extract_aws_account_id(arn):\n    \"\"\"\n    Extract the AWS account ID from a given ARN string.\n    \n    Args:\n        arn (str): The full AWS ARN string\n    \n    Returns:\n        str: The AWS account ID, or None if the ARN is invalid\n    \"\"\"\n    # Check if the ARN is None or an empty string\n    if not arn:\n        return None\n    \n    # Split the ARN into its components\n    try:\n        # Typical ARN format: arn:aws:service:region:account-id:resource\n        arn_parts = arn.split(':')\n        \n        # Validate basic ARN structure\n        if len(arn_parts) < 5 or arn_parts[0] != 'arn' or arn_parts[1] != 'aws':\n            return None\n        \n        # The account ID is typically the 5th element (index 4)\n        account_id = arn_parts[4]\n        \n        # Validate that the account ID is a 12-digit number\n        if not account_id.isdigit() or len(account_id) != 12:\n            return None\n        \n        return account_id\n    \n    except Exception:\n        # Catch any unexpected errors during parsing\n        return None\n\n# Example usage and test cases\ndef test_extract_aws_account_id():\n    # Test cases\n    test_arns = [\n        'arn:aws:iam::123456789012:user/username',\n        'arn:aws:s3:::bucket-name',\n        'arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0',\n        'invalid-arn',\n        None,\n        ''\n    ]\n    \n    for arn in test_arns:\n        account_id = extract_aws_account_id(arn)\n        print(f\"ARN: {arn}\")\n        print(f\"Account ID: {account_id}\\n\")\n\n# Run the test cases\ntest_extract_aws_account_id()\n```\n\nThis implementation has several key features:\n\n1. Robust error handling\n2. Validates the basic ARN structure\n3. Checks that the account ID is a 12-digit number\n4. Handles various edge cases like None, empty string, or invalid ARN\n\nThe function works as follows:\n- Splits the ARN string by ':'\n- Validates the ARN starts with 'arn:aws'\n- Extracts the account ID (5th element)\n- Validates the account ID is a 12-digit number\n- Returns the account ID or None if invalid\n\nExample outputs:\n```\nARN: arn:aws:iam::123456789012:user/username\nAccount ID: 123456789012\n\nARN: arn:aws:s3:::bucket-name\nAccount ID: None\n\nARN: arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: invalid-arn\nAccount ID: None\n\nARN: None\nAccount ID: None\n\nARN: \nAccount ID: None\n```\n\nThis implementation provides a flexible and robust way to extract AWS account IDs from ARN strings with comprehensive error handling.",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID from an ARN string"
#     },
#     "score": 8,
#     "reasoning": "The solution provides a robust, well-structured approach to extracting AWS account IDs from ARN strings. It handles multiple edge cases effectively and demonstrates good defensive programming practices. While functional, there are opportunities for enhanced type safety and more granular error handling."
#   },
#   {
#     "output": "Here's a solution to validate an AWS S3 bucket name using a regular expression:\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name):\n    # AWS S3 bucket name validation regex pattern\n    pattern = r'^[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$'\n    \n    return bool(re.match(pattern, bucket_name))\n\n# Test cases\ntest_cases = [\n    \"my-bucket\",            # Valid\n    \"my.bucket\",            # Valid\n    \"my-bucket-123\",        # Valid\n    \"123-my-bucket\",        # Valid\n    \"MY-BUCKET\",            # Invalid (uppercase)\n    \"my bucket\",            # Invalid (spaces)\n    \"ab\",                   # Invalid (too short)\n    \"my-bucket-with-a-very-long-name-that-exceeds-63-characters\"  # Invalid (too long)\n]\n\n# Run test cases\nfor bucket in test_cases:\n    print(f\"{bucket}: {is_valid_s3_bucket_name(bucket)}\")\n```\n\nLet's break down the regex pattern `^[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$`:\n\n- `^` : Start of the string\n- `[a-z0-9]` : First character must be lowercase letter or number\n- `[a-z0-9.-]{1,61}` : 1-61 characters that can be lowercase letters, numbers, dots, or hyphens\n- `[a-z0-9]` : Last character must be lowercase letter or number\n- `$` : End of the string\n\nThis regex ensures:\n- Lowercase only\n- 3-63 characters long\n- Starts and ends with a letter or number\n- Can include dots and hyphens in the middle\n- No spaces allowed\n\nThe function returns `True` for valid bucket names and `False` for invalid ones.",
#     "test_case": {
#       "task": "Develop a regex pattern to validate an AWS S3 bucket name according to naming conventions (lowercase, no spaces, 3-63 characters)"
#     },
#     "score": 8,
#     "reasoning": "The solution provides a robust regex-based approach to S3 bucket name validation, covering most key requirements. The implementation is clean, well-structured, and demonstrates thorough understanding of AWS naming conventions. However, it lacks some nuanced validation rules and error reporting."
#   }
# ]
