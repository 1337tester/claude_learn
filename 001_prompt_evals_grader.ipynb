# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
from statistics import mean

load_dotenv()

client = Anthropic()
model = "claude-3-5-haiku-latest"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
print(dataset)

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)
# Out:
# [{'task': 'Write a Python function that extracts the AWS region from an EC2 instance ARN (Amazon Resource Name)'}, {'task': 'Create a JSON configuration for an AWS Lambda function event trigger from an S3 bucket'}, {'task': 'Develop a regular expression to validate a standard AWS access key ID format (AKIAIOSFODNN7EXAMPLE)'}]

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
        You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

        Original Task:
        <task>
        {test_case["task"]}
        </task>

        Solution to Evaluate:
        <solution>
        {output}
        </solution>

        Output Format
        Provide your evaluation as a structured JSON object with the following fields, in this specific order:
        - "strengths": An array of 1-3 key strengths
        - "weaknesses": An array of 1-3 key areas for improvement
        - "reasoning": A concise explanation of your overall assessment
        - "score": A number between 1-10

        Respond with JSON. Keep your response concise and direct.
        Example response shape:
        {{
            "strengths": string[],
            "weaknesses": string[],
            "reasoning": string,
            "score": number
        }}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "´´´json")
    eval_text = chat(messages, stop_sequences=["´´´"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt=f"""
        Please solve the following task:

        {test_case["task"]}
        """
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "Here's a Python function that extracts the AWS region from an EC2 instance ARN:\n\n```python\ndef extract_aws_region_from_arn(arn):\n    \"\"\"\n    Extracts the AWS region from an EC2 instance ARN.\n    \n    Args:\n    arn (str): The full ARN of an EC2 instance\n    \n    Returns:\n    str: The AWS region extracted from the ARN, or None if the ARN is invalid\n    \"\"\"\n    # Check if the ARN is a valid format\n    if not arn or not isinstance(arn, str):\n        return None\n    \n    # Split the ARN into its components\n    arn_parts = arn.split(':')\n    \n    # Validate the basic ARN structure\n    if len(arn_parts) < 5:\n        return None\n    \n    # Check if it's an AWS ARN\n    if arn_parts[0] != 'arn' or arn_parts[1] != 'aws':\n        return None\n    \n    # The region is the 4th part of the ARN\n    region = arn_parts[3]\n    \n    return region\n\n# Test cases\ndef test_extract_aws_region_from_arn():\n    # Valid ARN cases\n    assert extract_aws_region_from_arn('arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0') == 'us-west-2'\n    assert extract_aws_region_from_arn('arn:aws:ec2:eu-central-1:987654321098:instance/i-0987654321fedcba0') == 'eu-central-1'\n    \n    # Invalid ARN cases\n    assert extract_aws_region_from_arn(None) is None\n    assert extract_aws_region_from_arn('') is None\n    assert extract_aws_region_from_arn('invalid-arn') is None\n    assert extract_aws_region_from_arn('arn:aws:s3:us-west-2:123456789012:bucket') is None\n    \n    print(\"All test cases passed!\")\n\n# Run the tests\ntest_extract_aws_region_from_arn()\n```\n\nThis solution provides a robust way to extract the AWS region from an EC2 instance ARN with several key features:\n\n1. **Input Validation**:\n   - Checks if the input is a non-empty string\n   - Validates the basic ARN structure\n   - Ensures the ARN starts with 'arn:aws'\n\n2. **Region Extraction**:\n   - Splits the ARN by ':'\n   - Extracts the region from the 4th part of the ARN\n\n3. **Error Handling**:\n   - Returns `None` for invalid inputs\n   - Handles various edge cases\n\n4. **Test Cases**:\n   - Includes comprehensive test cases covering:\n     - Valid ARNs with different regions\n     - `None` input\n     - Empty string\n     - Invalid ARN formats\n     - Non-EC2 ARNs\n\nExample usage:\n```python\n# Example usage\narn1 = 'arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0'\nregion1 = extract_aws_region_from_arn(arn1)\nprint(region1)  # Output: us-west-2\n\narn2 = 'arn:aws:ec2:eu-central-1:987654321098:instance/i-0987654321fedcba0'\nregion2 = extract_aws_region_from_arn(arn2)\nprint(region2)  # Output: eu-central-1\n```\n\nThe function successfully handles various ARN formats and provides a clean, simple way to extract the AWS region.\n\nKey points about the ARN structure:\n- Format: `arn:aws:service:region:account-id:resource-type/resource-id`\n- The region is always the 4th component\n- Follows AWS ARN naming conventions\n\nThis implementation is flexible and can be easily integrated into larger AWS-",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an EC2 instance ARN (Amazon Resource Name)"
#     },
#     "score": 8,
#     "reasoning": "The solution provides a solid, pragmatic approach to extracting AWS regions from EC2 instance ARNs. It demonstrates strong defensive programming techniques with input validation and error handling. The implementation is simple, readable, and effectively solves the core problem with minimal complexity."
#   },
#   {
#     "output": "Here's a comprehensive JSON configuration for an AWS Lambda function event trigger from an S3 bucket:\n\n```json\n{\n    \"AWSTemplateFormatVersion\": \"2010-09-09\",\n    \"Description\": \"AWS Lambda S3 Event Trigger Configuration\",\n    \"Resources\": {\n        \"S3BucketEventTrigger\": {\n            \"Type\": \"AWS::Lambda::Permission\",\n            \"Properties\": {\n                \"Action\": \"lambda:InvokeFunction\",\n                \"FunctionName\": \"MyLambdaFunction\",\n                \"Principal\": \"s3.amazonaws.com\",\n                \"SourceArn\": \"arn:aws:s3:::my-source-bucket\"\n            }\n        },\n        \"S3BucketNotification\": {\n            \"Type\": \"AWS::S3::Bucket\",\n            \"Properties\": {\n                \"BucketName\": \"my-source-bucket\",\n                \"NotificationConfiguration\": {\n                    \"LambdaConfigurations\": [\n                        {\n                            \"Event\": \"s3:ObjectCreated:*\",\n                            \"Function\": \"arn:aws:lambda:us-east-1:123456789012:function:MyLambdaFunction\",\n                            \"Filter\": {\n                                \"S3Key\": {\n                                    \"Rules\": [\n                                        {\n                                            \"Name\": \"prefix\",\n                                            \"Value\": \"uploads/\"\n                                        },\n                                        {\n                                            \"Name\": \"suffix\", \n                                            \"Value\": \".jpg\"\n                                        }\n                                    ]\n                                }\n                            }\n                        }\n                    ]\n                }\n            }\n        }\n    }\n}\n```\n\nThis JSON configuration provides a comprehensive setup for an AWS Lambda function triggered by S3 bucket events. Let me break down the key components:\n\n1. AWS CloudFormation Template Format\n- Uses standard AWS CloudFormation template structure\n- Includes version and description\n\n2. Lambda Permission Resource\n- Grants S3 permission to invoke the Lambda function\n- Specifies source bucket ARN\n- Defines the Lambda function to be triggered\n\n3. S3 Bucket Notification Configuration\n- Configures event trigger details\n- Specifies event type (e.g., object creation)\n- Provides Lambda function ARN\n- Includes optional filtering rules\n\nKey Configuration Options:\n- Event Types:\n  - \"s3:ObjectCreated:*\"\n  - \"s3:ObjectCreated:Put\"\n  - \"s3:ObjectRemoved:Delete\"\n\n- Filter Rules:\n  - Prefix: Limit events to specific folder\n  - Suffix: Filter by file extension\n\nCustomization Points:\n- Replace \"MyLambdaFunction\" with your actual Lambda function name\n- Update ARN with your AWS account and region\n- Modify event types and filter rules as needed\n\nAdditional Best Practices:\n- Use IAM roles for secure access\n- Implement proper error handling in Lambda function\n- Configure appropriate timeout and memory settings\n\nThis configuration provides a flexible and robust way to trigger Lambda functions based on S3 bucket events.",
#     "test_case": {
#       "task": "Create a JSON configuration for an AWS Lambda function event trigger from an S3 bucket"
#     },
#     "score": 7,
#     "reasoning": "The solution provides a solid foundation for S3-triggered Lambda events with clear structure and configuration options. While technically sound, it lacks some advanced configuration practices for production-grade infrastructure-as-code."
#   },
#   {
#     "output": "Here's a regular expression to validate a standard AWS access key ID format:\n\n```regex\n^AKIA[A-Z0-9]{16}$\n```\n\nLet's break down the regex:\n\n- `^` - Start of the string\n- `AKIA` - The standard prefix for AWS access key IDs\n- `[A-Z0-9]{16}` - 16 characters that can be uppercase letters or digits\n- `$` - End of the string\n\nExample validation in different programming languages:\n\nPython:\n```python\nimport re\n\ndef validate_aws_access_key(key):\n    pattern = r'^AKIA[A-Z0-9]{16}$'\n    return re.match(pattern, key) is not None\n\n# Test cases\nprint(validate_aws_access_key('AKIAIOSFODNN7EXAMPLE'))  # True\nprint(validate_aws_access_key('AKIA1234567890ABCDEF'))  # True\nprint(validate_aws_access_key('AKIA123'))  # False\n```\n\nJavaScript:\n```javascript\nfunction validateAwsAccessKey(key) {\n    const pattern = /^AKIA[A-Z0-9]{16}$/;\n    return pattern.test(key);\n}\n\n// Test cases\nconsole.log(validateAwsAccessKey('AKIAIOSFODNN7EXAMPLE'));  // true\nconsole.log(validateAwsAccessKey('AKIA1234567890ABCDEF'));  // true\nconsole.log(validateAwsAccessKey('AKIA123'));  // false\n```\n\nKey points:\n- Starts with 'AKIA'\n- Followed by exactly 16 uppercase letters or digits\n- Total length is exactly 20 characters\n\nNote: This regex validates the format, but doesn't confirm if the key is a real, active AWS access key.",
#     "test_case": {
#       "task": "Develop a regular expression to validate a standard AWS access key ID format (AKIAIOSFODNN7EXAMPLE)"
#     },
#     "score": 7,
#     "reasoning": "The solution offers a solid basic regex validation for traditional AWS access key IDs with proper structure and implementation across languages. However, it oversimplifies the validation by not considering potential evolving AWS key generation standards or advanced security checks."
#   }
# ]
