# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calcullate PI to the 5th digit.
    
    Then create a ./test.py file that tests the function.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate PI to the 5th digit in main.py and then create a test file for it.
# Now I'll add a function to calculate PI to the 5th digit:
# Now let's create the test.py file:
# Perfect! Let me verify the files were created correctly:
# Excellent! I've successfully completed both tasks:
#
# ## **main.py** - Added `calculate_pi()` function
# The function calculates PI to 5 decimal places (3.14159) using the **Leibniz formula**:
# - π = 4 × (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)
# - Uses 500,000 iterations to ensure accuracy to 5 decimal places
# - Returns the result rounded to 5 decimal places
#
# ## **test.py** - Comprehensive test suite
# Created a test file with 4 test cases:
# 1. **test_pi_value**: Verifies the calculated value equals 3.14159
# 2. **test_pi_return_type**: Ensures the function returns a float
# 3. **test_pi_range**: Checks that PI is within the expected range (3.14 < π < 3.15)
# 4. **test_pi_precision**: Validates that the result has at most 5 decimal places
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
#
# Or if you want verbose output:
# ```bash
# python test.py -v
# ```
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calcullate PI to the 5th digit.\n\n    Then create a ./test.py file that tests the function.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate PI to the 5th digit in main.py and then create a test file for it.", type='text'),
#    ToolUseBlock(id='toolu_01LwwhNtnjTfoQx4xX8EAqEJ', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01LwwhNtnjTfoQx4xX8EAqEJ',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello there!\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate PI to the 5th digit:", type='text'),
#    ToolUseBlock(id='toolu_013my9JbSLU1n5u3EdU4ikic', input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hello there!")', 'new_str': 'def greeting():\n    print("Hello there!")\n\n\ndef calculate_pi():\n    """\n    Calculate PI to the 5th decimal digit using the Leibniz formula.\n    Returns PI approximation: 3.14159\n    """\n    # Using the Leibniz formula: π = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\n    # We need enough iterations to get accuracy to 5 decimal places\n    pi_approximation = 0.0\n    iterations = 500000  # Sufficient iterations for 5 decimal places\n    \n    for i in range(iterations):\n        pi_approximation += ((-1) ** i) / (2 * i + 1)\n    \n    pi_approximation *= 4\n    \n    # Round to 5 decimal places\n    return round(pi_approximation, 5)'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_013my9JbSLU1n5u3EdU4ikic',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create the test.py file:", type='text'),
#    ToolUseBlock(id='toolu_01M3u7i3q77WSYsz562DPys5', input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nfrom main import calculate_pi\n\n\nclass TestCalculatePI(unittest.TestCase):\n    """Test suite for the calculate_pi function"""\n    \n    def test_pi_value(self):\n        """Test that PI is calculated to 5 decimal places correctly"""\n        result = calculate_pi()\n        expected = 3.14159\n        self.assertEqual(result, expected, \n                        f"Expected PI to be {expected}, but got {result}")\n    \n    def test_pi_return_type(self):\n        """Test that the function returns a float"""\n        result = calculate_pi()\n        self.assertIsInstance(result, float, \n                             "calculate_pi should return a float")\n    \n    def test_pi_range(self):\n        """Test that PI is within the expected range"""\n        result = calculate_pi()\n        self.assertGreater(result, 3.14, "PI should be greater than 3.14")\n        self.assertLess(result, 3.15, "PI should be less than 3.15")\n    \n    def test_pi_precision(self):\n        """Test that PI has at most 5 decimal places"""\n        result = calculate_pi()\n        # Convert to string and check decimal places\n        result_str = str(result)\n        if \'.\' in result_str:\n            decimal_places = len(result_str.split(\'.\')[1])\n            self.assertLessEqual(decimal_places, 5, \n                                "PI should have at most 5 decimal places")\n\n\nif __name__ == \'__main__\':\n    unittest.main()\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01M3u7i3q77WSYsz562DPys5',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_01XTLxv3nBofdjrszG7poRc8', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use'),
#    ToolUseBlock(id='toolu_019q9nDXCNK6KxCcgnm16jEq', input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01XTLxv3nBofdjrszG7poRc8',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello there!\\")\\n3: \\n4: \\n5: def calculate_pi():\\n6:     \\"\\"\\"\\n7:     Calculate PI to the 5th decimal digit using the Leibniz formula.\\n8:     Returns PI approximation: 3.14159\\n9:     \\"\\"\\"\\n10:     # Using the Leibniz formula: \\u03c0 = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\\n11:     # We need enough iterations to get accuracy to 5 decimal places\\n12:     pi_approximation = 0.0\\n13:     iterations = 500000  # Sufficient iterations for 5 decimal places\\n14:     \\n15:     for i in range(iterations):\\n16:         pi_approximation += ((-1) ** i) / (2 * i + 1)\\n17:     \\n18:     pi_approximation *= 4\\n19:     \\n20:     # Round to 5 decimal places\\n21:     return round(pi_approximation, 5)"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_019q9nDXCNK6KxCcgnm16jEq',
#     'content': '"1: import unittest\\n2: from main import calculate_pi\\n3: \\n4: \\n5: class TestCalculatePI(unittest.TestCase):\\n6:     \\"\\"\\"Test suite for the calculate_pi function\\"\\"\\"\\n7:     \\n8:     def test_pi_value(self):\\n9:         \\"\\"\\"Test that PI is calculated to 5 decimal places correctly\\"\\"\\"\\n10:         result = calculate_pi()\\n11:         expected = 3.14159\\n12:         self.assertEqual(result, expected, \\n13:                         f\\"Expected PI to be {expected}, but got {result}\\")\\n14:     \\n15:     def test_pi_return_type(self):\\n16:         \\"\\"\\"Test that the function returns a float\\"\\"\\"\\n17:         result = calculate_pi()\\n18:         self.assertIsInstance(result, float, \\n19:                              \\"calculate_pi should return a float\\")\\n20:     \\n21:     def test_pi_range(self):\\n22:         \\"\\"\\"Test that PI is within the expected range\\"\\"\\"\\n23:         result = calculate_pi()\\n24:         self.assertGreater(result, 3.14, \\"PI should be greater than 3.14\\")\\n25:         self.assertLess(result, 3.15, \\"PI should be less than 3.15\\")\\n26:     \\n27:     def test_pi_precision(self):\\n28:         \\"\\"\\"Test that PI has at most 5 decimal places\\"\\"\\"\\n29:         result = calculate_pi()\\n30:         # Convert to string and check decimal places\\n31:         result_str = str(result)\\n32:         if \'.\' in result_str:\\n33:             decimal_places = len(result_str.split(\'.\')[1])\\n34:             self.assertLessEqual(decimal_places, 5, \\n35:                                 \\"PI should have at most 5 decimal places\\")\\n36: \\n37: \\n38: if __name__ == \'__main__\':\\n39:     unittest.main()\\n40: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Excellent! I've successfully completed both tasks:\n\n## **main.py** - Added `calculate_pi()` function\nThe function calculates PI to 5 decimal places (3.14159) using the **Leibniz formula**:\n- π = 4 × (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\n- Uses 500,000 iterations to ensure accuracy to 5 decimal places\n- Returns the result rounded to 5 decimal places\n\n## **test.py** - Comprehensive test suite\nCreated a test file with 4 test cases:\n1. **test_pi_value**: Verifies the calculated value equals 3.14159\n2. **test_pi_return_type**: Ensures the function returns a float\n3. **test_pi_range**: Checks that PI is within the expected range (3.14 < π < 3.15)\n4. **test_pi_precision**: Validates that the result has at most 5 decimal places\n\nYou can run the tests by executing:\n```bash\npython test.py\n```\n\nOr if you want verbose output:\n```bash\npython test.py -v\n```", type='text')]}]
